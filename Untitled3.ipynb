# %%
X=int(input())
A=X//60
B=X/60-A
print(A,B)
# Out:
#  480
# 8 0.0

# %%
X=int(input())
A=X//60
B=(X/60-A)*60
print(A,B)
# Out:
#  512
# 8 0.5333333333333332

# %%
X=int(input())
A=X//60
B=X-A*60
print(A,B)
# Out:
#  512
# 8 31.999999999999993

# %%
X=int(input())
A=X//60
B=X-A*60
print(A,B)
# Out:
#  512
# 8 32

# %%
X=int(input())
A=X//60
B=X-A*60
print(A,B)
# Out:
#  480
# 8 0

# %%
X=int(input())
H=int(input)
M=int(input())
A=X/60+H
B=X-60*A
print(A)
print(B)
# Out:
#  480
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 X=int(input())
# ----> 2 H=int(input)
#       3 M=int(input())
#       4 A=X/60+H
#       5 B=X-60*A
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'method'

# %%
X=int(input())
H=int(input)
M=int(input())
A=X/60+H
B=X-60*A
print(A)
print(B)
# Out:
#  480
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 X=int(input())
# ----> 2 H=int(input)
#       3 M=int(input())
#       4 A=X/60+H
#       5 B=X-60*A
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'method'

# %%
X=int(input())
H=int(input())
M=int(input())
A=X/60+H
B=X-60*A
print(A)
print(B)
# Out:
#  480 1 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 X=int(input())
#       2 H=int(input)
#       3 M=int(input())
#       4 A=X/60+H
#
# ValueError: invalid literal for int() with base 10: '480 1 2'

# %%
X=int(input())
H=int(input())
M=int(input())
A=X/60+H
B=X-X/60+M
print(A)
print(B)
# Out:
#  480
#  1
#  2
# 9.0
# -58.0

# %%
X=int(input())
H=int(input())
M=int(input())
A=X/60+H
B=X/60+M
print(A)
print(B)
# Out:
#  480
#  1
#  2
# 9.0
# 474.0

# %%
X=int(input())
H=int(input())
M=int(input())
A=X/60+H
B=(X//60-X/60)*100+M
print(A)
print(B)
# Out:
#  480
#  1
#  2
# 9.0
# 10.0

# %%
X=int(input())
H=int(input())
M=int(input())
A=X/60+H
B=(X//60-X/60)*100+M
print(A)
print(B)
# Out:
#  480
#  1
#  2
# 9.0
# 2.0

# %%
X=int(input())
H=int(input())
M=int(input())
A=X/60+H
B=X-60*A+M
print(A)
print(B)
# Out:
#  475
#  1
#  55
# 8.916666666666668
# -36.6666666666667

# %%
X=int(input())
H=int(input())
M=int(input())
A=X/60+H
B=60*A-X+M
print(A)
print(B)
# Out:
#  480
#  1
#  2
# 9.0
# -58.0

# %%
X=int(input())
H=int(input())
M=int(input())
S=X+H*60+M
A=S//60
B=S%60
print(A)
print(B)
# Out:
#  475
#  1
#  55
# 9
# 50
